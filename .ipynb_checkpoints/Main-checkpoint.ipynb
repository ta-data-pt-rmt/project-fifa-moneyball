# %%
import pandas as pd
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
fifa = pd.read_csv('fifa21_male2.csv')
fifa.shape
# Out:
# C:\dataanalyst\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (78) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# (17125, 107)

# %%
fifa.describe()
# Out:
#                   ID           Age           OVA           BOV           POT  \
# count   17125.000000  17125.000000  17125.000000  17125.000000  17125.000000
# mean   219388.716204     25.272934     66.965022     67.900204     72.489810
# std     37499.197507      4.942665      6.864329      6.637538      5.769949
# min         2.000000     16.000000     38.000000     42.000000     47.000000
# 25%    204082.000000     21.000000     62.000000     64.000000     69.000000
# 50%    228961.000000     25.000000     67.000000     68.000000     72.000000
# 75%    243911.000000     29.000000     72.000000     72.000000     76.000000
# max    259105.000000     53.000000     93.000000     93.000000     95.000000
#
#              Growth     Attacking      Crossing     Finishing  \
# count  17125.000000  17125.000000  17125.000000  17125.000000
# mean       5.524788    258.537752     51.621314     47.956672
# std        5.787539     72.255687     17.875715     19.391547
# ...

# %%
fifa.describe().columns
# Out:
# Index(['ID', 'Age', 'OVA', 'BOV', 'POT', 'Growth', 'Attacking', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill',
#        'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control',
#        'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions',
#        'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength',
#        'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning',
#        'Vision', 'Penalties', 'Composure', 'Defending', 'Marking',
#        'Standing Tackle', 'Sliding Tackle', 'Goalkeeping', 'GK Diving',
#        'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes',
#        'Total Stats', 'Base Stats', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY'],
#       dtype='object')

# %%
fifa.select_dtypes('object').columns
# Out:
# Index(['Name', 'Nationality', 'Club', 'BP', 'Position', 'Player Photo',
#        'Club Logo', 'Flag Photo', 'Team & Contract', 'Height', 'Weight',
#        'foot', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause',
#        'Contract', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'Hits', 'LS', 'ST', 'RS',
#        'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM',
#        'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'GK', 'Gender'],
#       dtype='object')

# %%
fifa[['Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill',
       'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control',
       'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions',
       'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength',
       'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning',
       'Vision', 'Penalties', 'Composure', 'Defending', 'Marking',]]
# Out:
#        Finishing  Heading Accuracy  Short Passing  Volleys  Skill  Dribbling  \
# 0             50                59             71     58.0    338         73
# 1             64                61             76     68.0    369         69
# 2             64                41             77     75.0    387         79
# 3             70                60             80      NaN    255         68
# 4             69                54             90     79.0    408         85
# ...          ...               ...            ...      ...    ...        ...
# 17120         23                66             47     26.0    193         44
# 17121         43                50             64     41.0    264         57
# 17122         34                53             42     34.0    212         52
# 17123         26                52             60     23.0    258         55
# 17124         64                59             45     54.0    235         57
#
# ...

# %%
fifa[['BP','Position',"Penalties",'Attacking']]
# Out:
#         BP      Position  Penalties  Attacking
# 0      LWB            LM         50        313
# 1       CM    CM CAM CDM         75        337
# 2      CAM  CAM RM RW LM         66        337
# 3       ST           NaN         70        264
# 4      CAM        CM CAM         71        367
# ...    ...           ...        ...        ...
# 17120   CB            CB         39        197
# 17121  CAM        CAM CM         50        248
# 17122   RB            RB         49        218
# 17123   RB         RB LB         36        223
# 17124   ST            ST         67        254
#
# [17125 rows x 4 columns]

# %%
fifa.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  ...  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png  ...
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png  ...
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png  ...
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png  ...
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png  ...
#
#      CDM    RDM    RWB     LB   LCB    CB   RCB     RB    GK Gender
# ...

# %%
#What is the average age,ranges for the player with the hight individual scores
#Are the highest players the best to make goals with the head?
# correlation with hight vs goals with head.
#Which country provides the best players for each league, top2.
#Does the prices of the player is reflected by the avorale abbilitys or the attacking abillities?
#Could we predict a nationality, based on the player caracteristics, and team where it plays?
# Does a nationality, a provides specific kind of player?

# %%
fifa.head(10)
# Out:
#     ID           Name  Age  OVA            Nationality               Club  \
# 0    2    G. Pasquale   33   69                  Italy            Udinese
# 1   16    Luis García   37   71                  Spain          KAS Eupen
# 2   27        J. Cole   33   71                England      Coventry City
# 3   36       D. Yorke   36   68  Trinidad &amp; Tobago         Sunderland
# 4   41        Iniesta   36   81                  Spain        Vissel Kobe
# 5   61     D. Odonkor   27   66                Germany   Alemannia Aachen
# 6   80   E. Belözoğlu   38   77                 Turkey      Fenerbahçe SK
# 7  241       R. Giggs   39   78                  Wales  Manchester United
# 8  244  G. Neville  B   35   76                England  Manchester United
# 9  246     P. Scholes   37   80                England  Manchester United
#
#    BOV   BP      Position                                       Player Photo  \
# ...

# %%
# Which top 5 Countries has the best potential attack qualities (Taking in account the ones with possibility to go to the worl cup)

# %%
numplayerbycountry = fifa.groupby('Nationality').agg({'Name':'count','Attacking':'mean','OVA':'mean','Defending':'mean'}).sort_values(by='Name', ascending=False).reset_index()
numplayerbycountry
# Out:
#        Nationality  Name   Attacking        OVA   Defending
# 0          England  1707  243.161687  63.642648  139.484476
# 1          Germany  1154  247.870017  66.205373  139.844021
# 2            Spain  1121  270.064228  69.619982  147.611062
# 3           France   990  263.356566  67.792929  146.828283
# 4           Brazil   857  285.179697  72.004667  148.564761
# ..             ...   ...         ...        ...         ...
# 162  New Caledonia     1  233.000000  71.000000  209.000000
# 163      Nicaragua     1  263.000000  56.000000   81.000000
# 164      Indonesia     1  228.000000  56.000000  118.000000
# 165    Saint Lucia     1  233.000000  64.000000  186.000000
# 166      Palestine     1  279.000000  61.000000   56.000000
#
# [167 rows x 5 columns]

# %%
top20 = numplayerbycountry[:20]
top20
# Out:
#             Nationality  Name   Attacking        OVA   Defending
# 0               England  1707  243.161687  63.642648  139.484476
# 1               Germany  1154  247.870017  66.205373  139.844021
# 2                 Spain  1121  270.064228  69.619982  147.611062
# 3                France   990  263.356566  67.792929  146.828283
# 4                Brazil   857  285.179697  72.004667  148.564761
# 5             Argentina   778  271.858612  69.668380  145.800771
# 6                 Italy   565  261.355752  68.863717  143.017699
# 7           Netherlands   475  257.654737  67.795789  141.155789
# 8              Portugal   365  274.698630  70.569863  151.249315
# 9         United States   358  239.653631  64.201117  134.368715
# 10               Mexico   345  256.988406  66.385507  143.947826
# 11              Uruguay   335  262.456716  68.155224  142.262687
# 12             Colombia   305  266.295082  68.314754  142.144262
# ...

# %%
top20[['Nationality','Attacking']][top20['Attacking'] == top20['Attacking'].max()]
# Out:
#   Nationality   Attacking
# 4      Brazil  285.179697

# %%
plt.boxplot(numplayerbycountry['Name'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d13ea67490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d13ea1e310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d13ea67880>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d13ea1e520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d13eaf6160>],
#  'means': []}

# %%
numplayerbycountry.describe()
# Out:
#               Name   Attacking         OVA   Defending
# count   167.000000  167.000000  167.000000  167.000000
# mean    102.544910  261.893771   66.021127  135.256409
# std     225.488431   28.499901    3.836541   29.017460
# min       1.000000  154.500000   52.500000   46.000000
# 25%       3.500000  248.112903   63.900000  125.712218
# 50%      19.000000  260.416667   66.385507  139.823529
# 75%     108.500000  274.944444   68.583158  146.940457
# max    1707.000000  378.000000   76.000000  222.666667

# %%
numplayerbycountry.quantile()
# Out:
# Name          19.000000
# Attacking    260.416667
# OVA           66.385507
# Defending    139.823529
# Name: 0.5, dtype: float64

# %%
topcountry =numplayerbycountry[numplayerbycountry['Name']>= 350]
topcountry
# Out:
#      Nationality  Name   Attacking        OVA   Defending
# 0        England  1707  243.161687  63.642648  139.484476
# 1        Germany  1154  247.870017  66.205373  139.844021
# 2          Spain  1121  270.064228  69.619982  147.611062
# 3         France   990  263.356566  67.792929  146.828283
# 4         Brazil   857  285.179697  72.004667  148.564761
# 5      Argentina   778  271.858612  69.668380  145.800771
# 6          Italy   565  261.355752  68.863717  143.017699
# 7    Netherlands   475  257.654737  67.795789  141.155789
# 8       Portugal   365  274.698630  70.569863  151.249315
# 9  United States   358  239.653631  64.201117  134.368715

# %%
print()

# %%
topcountry.corr()
# Out:
#                Name  Attacking       OVA  Defending
# Name       1.000000  -0.214804 -0.339882  -0.067053
# Attacking -0.214804   1.000000  0.976647   0.915798
# OVA       -0.339882   0.976647  1.000000   0.872992
# Defending -0.067053   0.915798  0.872992   1.000000

# %%
#Which country provides the best players for each league, top2.

# %%
We realized, if we have all the countrys   have a few playes, so we decide to take the countrires with mo re playes, 
the more attacking  the mor OVA

# %%
witrh complement to do linear regration,

# %%
show insight to bar graoh  , attacking vs nationality

# %%
data = fifa.groupby(['Nationality','BP']).agg({'Name':'count','Attacking':'mean','Defending':'mean'}).reset_index().sort_values(by='Name', ascending=False)
data
# Out:
#      Nationality   BP  Name   Attacking   Defending
# 412      England   CB   353  219.172805  190.730878
# 425      England   ST   282  280.343972   78.287234
# 493      Germany   CB   260  232.511538  197.650000
# 451       France   CB   202  240.772277  205.019802
# 411      England  CAM   196  276.204082  135.974490
# ..           ...  ...   ...         ...         ...
# 574     Honduras   LM     1  327.000000   50.000000
# 575     Honduras  LWB     1  254.000000  198.000000
# 577     Honduras   RM     1  294.000000   88.000000
# 580    Hong Kong   CM     1  258.000000  145.000000
# 0    Afghanistan   CM     1  265.000000  163.000000
#
# [1342 rows x 5 columns]

# %%
data1 = data[data['Name']>50].sort_values(by='Nationality', ascending=False)
data1["BP"].unique()
data1[data1["BP"] == "ST"].sort_values(by='Attacking', ascending=False)
# Out:
#       Nationality  BP  Name   Attacking  Defending
# 161        Brazil  ST   123  323.260163  76.479675
# 54      Argentina  ST   117  320.589744  85.487179
# 1160        Spain  ST   147  313.925170  80.278912
# 658         Italy  ST    92  313.913043  77.826087
# 865   Netherlands  ST    72  309.847222  87.236111
# 276      Colombia  ST    61  307.360656  87.934426
# 1294      Uruguay  ST    62  307.241935  78.080645
# 464        France  ST   150  306.306667  73.960000
# 893       Nigeria  ST    56  295.107143  81.696429
# 506       Germany  ST   160  294.112500  78.962500
# 425       England  ST   282  280.343972  78.287234

# %%
# Does the hight influence into  have more higer or lowe skill

# %%
#Does Agression is more likely found in a particular position?
